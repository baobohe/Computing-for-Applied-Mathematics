# %% [markdown]
# Randomly generated normal variables follows the Box-Muller transform.
# ![image.png](attachment:3000e3d8-3104-4aa8-84ed-276a820e3b3e.png)
# What it does is that it takes two uniformly random variables X, Y and convert them into randomly normal samples.
#
# There is also another useful and common technique to generate random samples for a specific disribution called
# Inverse transform method.
# ![image.png](attachment:14793ea2-e0a2-46c3-911d-6c307fbcb07f.png)
#
# ![image.png](attachment:149b7a94-07f2-4b3d-a430-cc6792fed31e.png)
